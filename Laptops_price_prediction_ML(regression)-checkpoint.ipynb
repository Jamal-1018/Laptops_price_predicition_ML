# %%
# Importing libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %%
url = r'C:\Users\Jamal\Desktop\Datasets\laptops_cleaned.csv'
DATA = pd.read_csv(url)
DATA
# Out:
#       index Company            TypeName  Inches  screen_width  screen_height  \
# 0         1   Apple           Ultrabook    13.3          2560           1600
# 1         2   Apple           Ultrabook    13.3          1440            900
# 2         3      HP            Notebook    15.6          1920           1080
# 3         4   Apple           Ultrabook    15.4          2880           1800
# 4         5   Apple           Ultrabook    13.3          2560           1600
# ...     ...     ...                 ...     ...           ...            ...
# 1267   1299  Lenovo  2 in 1 Convertible    14.0          1920           1080
# 1268   1300  Lenovo  2 in 1 Convertible    13.3          3200           1800
# 1269   1301  Lenovo            Notebook    14.0          1366            768
# 1270   1302      HP            Notebook    15.6          1366            768
# 1271   1303    Asus            Notebook    15.6          1366            768
#
#       touchscreen cpu_brand    cpu_name  cpu_speed  Ram    memory_type  \
# 0               0     Intel     Core i5        2.3    8            SSD
# 1               0     Intel     Core i5        1.8    8  Flash storage
# 2               0     Intel    i5 7200U        2.5    8            SSD
# 3               0     Intel     Core i7        2.7   16            SSD
# 4               0     Intel     Core i5        3.1    8            SSD
# ...           ...       ...         ...        ...  ...            ...
# 1267            1     Intel    i7 6500U        2.5    4            SSD
# 1268            1     Intel    i7 6500U        2.5   16            SSD
# 1269            0     Intel  Core N3050        1.6    2  Flash storage
# 1270            0     Intel    i7 6500U        2.5    6            HDD
# 1271            0     Intel  Core N3050        1.6    4            HDD
#
#       primary_storage  secondary_storage gpu_brand    OpSys  Weight   price
# 0                 128                  0     Intel    macOS       1   71379
# 1                 128                  0     Intel    macOS       1   47896
# 2                 256                  0     Intel      NaN       2   30636
# 3                 512                  0       AMD    macOS       2  135195
# 4                 256                  0     Intel    macOS       1   96096
# ...               ...                ...       ...      ...     ...     ...
# 1267              128                  0     Intel  windows       2   33993
# 1268              512                  0     Intel  windows       1   79867
# 1269               64                  0     Intel  windows       2   12201
# 1270             1024                  0       AMD  windows       2   40706
# 1271              500                  0     Intel  windows       2   19660
#
# [1272 rows x 18 columns]

# %%
# first 10 rows of data
DATA.head(10)
# Out:
#    index Company   TypeName  Inches  screen_width  screen_height  touchscreen  \
# 0      1   Apple  Ultrabook    13.3          2560           1600            0
# 1      2   Apple  Ultrabook    13.3          1440            900            0
# 2      3      HP   Notebook    15.6          1920           1080            0
# 3      4   Apple  Ultrabook    15.4          2880           1800            0
# 4      5   Apple  Ultrabook    13.3          2560           1600            0
# 5      6    Acer   Notebook    15.6          1366            768            0
# 6      7   Apple  Ultrabook    15.4          2880           1800            0
# 7      8   Apple  Ultrabook    13.3          1440            900            0
# 8      9    Asus  Ultrabook    14.0          1920           1080            0
# 9     10    Acer  Ultrabook    14.0          1920           1080            0
#
#   cpu_brand        cpu_name  cpu_speed  Ram    memory_type  primary_storage  \
# 0     Intel         Core i5        2.3    8            SSD              128
# 1     Intel         Core i5        1.8    8  Flash storage              128
# 2     Intel        i5 7200U        2.5    8            SSD              256
# 3     Intel         Core i7        2.7   16            SSD              512
# 4     Intel         Core i5        3.1    8            SSD              256
# 5       AMD  A9-Series 9420        3.0    4            HDD              500
# 6     Intel         Core i7        2.2   16  Flash storage              256
# 7     Intel         Core i5        1.8    8  Flash storage              256
# 8     Intel        i7 8550U        1.8   16            SSD              512
# 9     Intel        i5 8250U        1.6    8            SSD              256
#
#    secondary_storage gpu_brand    OpSys  Weight   price
# 0                  0     Intel    macOS       1   71379
# 1                  0     Intel    macOS       1   47896
# 2                  0     Intel      NaN       2   30636
# 3                  0       AMD    macOS       2  135195
# 4                  0     Intel    macOS       1   96096
# 5                  0       AMD  windows       2   21312
# 6                  0     Intel    macOS       2  114018
# 7                  0     Intel    macOS       1   61736
# 8                  0    Nvidia  windows       1   79654
# 9                  0     Intel  windows       2   41026

# %%
# Lets take a copy of our dataset 
df = DATA.copy()
df
# Out:
#       index Company            TypeName  Inches  screen_width  screen_height  \
# 0         1   Apple           Ultrabook    13.3          2560           1600
# 1         2   Apple           Ultrabook    13.3          1440            900
# 2         3      HP            Notebook    15.6          1920           1080
# 3         4   Apple           Ultrabook    15.4          2880           1800
# 4         5   Apple           Ultrabook    13.3          2560           1600
# ...     ...     ...                 ...     ...           ...            ...
# 1267   1299  Lenovo  2 in 1 Convertible    14.0          1920           1080
# 1268   1300  Lenovo  2 in 1 Convertible    13.3          3200           1800
# 1269   1301  Lenovo            Notebook    14.0          1366            768
# 1270   1302      HP            Notebook    15.6          1366            768
# 1271   1303    Asus            Notebook    15.6          1366            768
#
#       touchscreen cpu_brand    cpu_name  cpu_speed  Ram    memory_type  \
# 0               0     Intel     Core i5        2.3    8            SSD
# 1               0     Intel     Core i5        1.8    8  Flash storage
# 2               0     Intel    i5 7200U        2.5    8            SSD
# 3               0     Intel     Core i7        2.7   16            SSD
# 4               0     Intel     Core i5        3.1    8            SSD
# ...           ...       ...         ...        ...  ...            ...
# 1267            1     Intel    i7 6500U        2.5    4            SSD
# 1268            1     Intel    i7 6500U        2.5   16            SSD
# 1269            0     Intel  Core N3050        1.6    2  Flash storage
# 1270            0     Intel    i7 6500U        2.5    6            HDD
# 1271            0     Intel  Core N3050        1.6    4            HDD
#
#       primary_storage  secondary_storage gpu_brand    OpSys  Weight   price
# 0                 128                  0     Intel    macOS       1   71379
# 1                 128                  0     Intel    macOS       1   47896
# 2                 256                  0     Intel      NaN       2   30636
# 3                 512                  0       AMD    macOS       2  135195
# 4                 256                  0     Intel    macOS       1   96096
# ...               ...                ...       ...      ...     ...     ...
# 1267              128                  0     Intel  windows       2   33993
# 1268              512                  0     Intel  windows       1   79867
# 1269               64                  0     Intel  windows       2   12201
# 1270             1024                  0       AMD  windows       2   40706
# 1271              500                  0     Intel  windows       2   19660
#
# [1272 rows x 18 columns]

# %%
cd 'C:\Users\Jamal\Desktop\Datasets\laptops_cleaned.csv'
# Out:
# [WinError 123] The filename, directory name, or volume label syntax is incorrect: "'C:\\Users\\Jamal\\Desktop\\Datasets\\laptops_cleaned.csv'"
# C:\Users\Jamal\Desktop\Datasets
